# %%
import math
print(math.pi)
math.e
math.fabs(-5)
math.factorial(10)
math.log(100)
math.log(6,2)
math.hypot(5,4)
math.radians(180.0)
# Out:
# 3.141592653589793
# 3.141592653589793

# %%
(7 + 1j) * 1j
# Out:
# (-1+7j)
